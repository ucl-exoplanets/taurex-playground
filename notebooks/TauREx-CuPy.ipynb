# %% [markdown]
# # TauREx-CuPy
#
# [TauREx-CuPy](https://pypi.org/project/taurex-cupy/) is a plugin for TauREx. That allows for drop-in replacement classes that give us CUDA-accelerated radiative transfer!!
#
# Lets setup:

# %%
# !pip install taurex corner

# !mkdir xsec/

#### Exomol H2O ####
! wget https://exomol.com/db/H2O/1H2-16O/POKAZATEL/1H2-16O__POKAZATEL__R15000_0.3-50mu.xsec.TauREx.h5 -P ./xsec/
#### Exomol CH4 ####
! wget https://exomol.com/db/CH4/12C-1H4/MM/12C-1H4__MM.R15000_0.3-50mu.xsec.TauREx.h5 -P ./xsec
#### Exomol NH3 ####
! wget https://exomol.com/db/NH3/14N-1H3/CoYuTe/14N-1H3__CoYuTe.R15000_0.3-50mu.xsec.TauREx.h5 -P ./xsec/
#### Exomol CO2 ####
! wget https://exomol.com/db/CO2/12C-16O2/UCL-4000/12C-16O2__UCL-4000.R15000_0.3-50mu.xsec.TauREx.h5 -P ./xsec/

# !mkdir cia

# !wget https://hitran.org/data/CIA/H2-H2_2011.cia -P ./cia
# !wget https://hitran.org/data/CIA/H2-He_2011.cia -P ./cia
# Out:
# Requirement already satisfied: taurex in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Collecting corner
#   Downloading corner-2.2.3-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: astropy>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from taurex) (7.0.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/dist-packages (from taurex) (8.1.8)
# Requirement already satisfied: configobj<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from taurex) (5.0.9)
# Requirement already satisfied: h5py<4.0.0,>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from taurex) (3.12.1)
# Requirement already satisfied: nestle<0.3.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from taurex) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from taurex) (1.26.4)
# Requirement already satisfied: pylightcurve<5.0.0,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from taurex) (4.0.4)
# Requirement already satisfied: scipy>=1.11.3 in /usr/local/lib/python3.11/dist-packages (from taurex) (1.13.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from taurex) (0.9.0)
# Requirement already satisfied: matplotlib>=2.1 in /usr/local/lib/python3.11/dist-packages (from corner) (3.10.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.11/dist-packages (from astropy>=5.0.0->taurex) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.10.28.0.34.7 in /usr/local/lib/python3.11/dist-packages (from astropy>=5.0.0->taurex) (0.2025.2.3.0.32.42)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=5.0.0->taurex) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=5.0.0->taurex) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1->corner) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1->corner) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1->corner) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1->corner) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1->corner) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1->corner) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1->corner) (2.8.2)
# Requirement already satisfied: emcee>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from pylightcurve<5.0.0,>=4.0.1->taurex) (3.1.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.17.0)
# Downloading corner-2.2.3-py3-none-any.whl (15 kB)
# Installing collected packages: corner
# Successfully installed corner-2.2.3
# mkdir: cannot create directory ‘xsec/’: File exists
# --2025-02-12 22:08:16--  https://exomol.com/db/H2O/1H2-16O/POKAZATEL/1H2-16O__POKAZATEL__R15000_0.3-50mu.xsec.TauREx.h5
# Resolving exomol.com (exomol.com)... 128.40.3.60
# Connecting to exomol.com (exomol.com)|128.40.3.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 365310072 (348M)
# Saving to: ‘./xsec/1H2-16O__POKAZATEL__R15000_0.3-50mu.xsec.TauREx.h5.1’
#
# 1H2-16O__POKAZATEL_ 100%[===================>] 348.39M  18.6MB/s    in 20s
#
# 2025-02-12 22:08:36 (17.7 MB/s) - ‘./xsec/1H2-16O__POKAZATEL__R15000_0.3-50mu.xsec.TauREx.h5.1’ saved [365310072/365310072]
#
# --2025-02-12 22:08:37--  https://exomol.com/db/CH4/12C-1H4/MM/12C-1H4__MM.R15000_0.3-50mu.xsec.TauREx.h5
# Resolving exomol.com (exomol.com)... 128.40.3.60
# Connecting to exomol.com (exomol.com)|128.40.3.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 365310264 (348M)
# Saving to: ‘./xsec/12C-1H4__MM.R15000_0.3-50mu.xsec.TauREx.h5.1’
#
# 12C-1H4__MM.R15000_ 100%[===================>] 348.39M  22.4MB/s    in 16s
#
# 2025-02-12 22:08:54 (21.2 MB/s) - ‘./xsec/12C-1H4__MM.R15000_0.3-50mu.xsec.TauREx.h5.1’ saved [365310264/365310264]
#
# --2025-02-12 22:08:54--  https://exomol.com/db/NH3/14N-1H3/CoYuTe/14N-1H3__CoYuTe.R15000_0.3-50mu.xsec.TauREx.h5
# Resolving exomol.com (exomol.com)... 128.40.3.60
# Connecting to exomol.com (exomol.com)|128.40.3.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 365310264 (348M)
# Saving to: ‘./xsec/14N-1H3__CoYuTe.R15000_0.3-50mu.xsec.TauREx.h5.1’
#
# 14N-1H3__CoYuTe.R15 100%[===================>] 348.39M  12.0MB/s    in 30s
#
# 2025-02-12 22:09:24 (11.6 MB/s) - ‘./xsec/14N-1H3__CoYuTe.R15000_0.3-50mu.xsec.TauREx.h5.1’ saved [365310264/365310264]
#
# --2025-02-12 22:09:25--  https://exomol.com/db/CO2/12C-16O2/UCL-4000/12C-16O2__UCL-4000.R15000_0.3-50mu.xsec.TauREx.h5
# Resolving exomol.com (exomol.com)... 128.40.3.60
# Connecting to exomol.com (exomol.com)|128.40.3.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 365310264 (348M)
# Saving to: ‘./xsec/12C-16O2__UCL-4000.R15000_0.3-50mu.xsec.TauREx.h5.1’
#
# 12C-16O2__UCL-4000. 100%[===================>] 348.39M  22.5MB/s    in 17s
#
# 2025-02-12 22:09:42 (21.1 MB/s) - ‘./xsec/12C-16O2__UCL-4000.R15000_0.3-50mu.xsec.TauREx.h5.1’ saved [365310264/365310264]
#
# mkdir: cannot create directory ‘cia’: File exists
# --2025-02-12 22:09:42--  https://hitran.org/data/CIA/H2-H2_2011.cia
# Resolving hitran.org (hitran.org)... 131.142.195.62
# Connecting to hitran.org (hitran.org)|131.142.195.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24824179 (24M)
# Saving to: ‘./cia/H2-H2_2011.cia.1’
#
# H2-H2_2011.cia.1    100%[===================>]  23.67M  21.6MB/s    in 1.1s
#
# 2025-02-12 22:09:43 (21.6 MB/s) - ‘./cia/H2-H2_2011.cia.1’ saved [24824179/24824179]
#
# --2025-02-12 22:09:43--  https://hitran.org/data/CIA/H2-He_2011.cia
# Resolving hitran.org (hitran.org)... 131.142.195.62
# Connecting to hitran.org (hitran.org)|131.142.195.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146854122 (140M)
# Saving to: ‘./cia/H2-He_2011.cia.1’
#
# H2-He_2011.cia.1    100%[===================>] 140.05M  41.8MB/s    in 3.8s
#
# 2025-02-12 22:09:48 (36.4 MB/s) - ‘./cia/H2-He_2011.cia.1’ saved [146854122/146854122]

# %% [markdown]
# Grab some data:

# %%
# !wget https://raw.githubusercontent.com/ucl-exoplanets/taurex3/refs/heads/main/examples/parfiles/quickstart.dat
# Out:
# --2025-02-12 22:09:48--  https://raw.githubusercontent.com/ucl-exoplanets/taurex3/refs/heads/main/examples/parfiles/quickstart.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10752 (10K) [text/plain]
# Saving to: ‘quickstart.dat.1’
#
# quickstart.dat.1    100%[===================>]  10.50K  --.-KB/s    in 0s
#
# 2025-02-12 22:09:48 (103 MB/s) - ‘quickstart.dat.1’ saved [10752/10752]

# %% [markdown]
# Setup our caches:

# %%
from taurex.cache import OpacityCache, CIACache

OpacityCache().set_opacity_path('./xsec/')
CIACache().set_cia_path('./cia/')
# Out:
# WARNING:taurex.data.citation:Pybtex not installed. Citation functionality disabled

# %% [markdown]
# Now lets install the plugin!

# %%
# !pip install taurex-cupy --no-deps
# Out:
# Requirement already satisfied: taurex-cupy in /usr/local/lib/python3.11/dist-packages (0.0.1)

# %% [markdown]
# # Building the CUDA model
#
# Lets take the standard model from before:

# %%
from taurex.temperature import Isothermal
from taurex.planet import Planet
from taurex.stellar import BlackbodyStar
from taurex.chemistry import TaurexChemistry, ConstantGas
from taurex.model import TransmissionModel
from taurex.contributions import AbsorptionContribution, RayleighContribution, CIAContribution

isothermal = Isothermal(T=1500.0)

chemistry = TaurexChemistry(fill_gases=['H2','He'],ratio=0.172)

chemistry.addGas(ConstantGas('H2O',mix_ratio=1.2e-4))
chemistry.addGas(ConstantGas('CH4',mix_ratio=1.2e-5))
chemistry.addGas(ConstantGas('NH3',mix_ratio=1.2e-6))
chemistry.addGas(ConstantGas('CO2',mix_ratio=1.2e-6))

tm_cpu = TransmissionModel(planet=Planet(planet_radius=1.0,planet_mass=1.0),
                       temperature_profile=isothermal,
                       chemistry=chemistry,
                       star=BlackbodyStar(temperature=5700.0,radius=1.0),
                       atm_min_pressure=1e-0,
                       atm_max_pressure=1e6,
                       nlayers=30)
tm_cpu.add_contribution(AbsorptionContribution())
tm_cpu.add_contribution(CIAContribution(cia_pairs=['H2-H2','H2-He']))
tm_cpu.add_contribution(RayleighContribution())
tm_cpu.build()

# %% [markdown]
# The CUDA version replaces the ``Model`` and ``Contributions`` with ``Cuda`` varients like so:

# %%
from taurex_cupy import TransmissionCudaModel
from taurex_cupy import AbsorptionCuda, CIACuda, RayleighCuda

tm_gpu = TransmissionCudaModel(planet=Planet(planet_radius=1.0,planet_mass=1.0),
                       temperature_profile=isothermal,
                       chemistry=chemistry,
                       star=BlackbodyStar(temperature=5700.0,radius=1.0),
                       atm_min_pressure=1e-0,
                       atm_max_pressure=1e6,
                       nlayers=30)
tm_gpu.add_contribution(AbsorptionCuda())
tm_gpu.add_contribution(CIACuda(cia_pairs=['H2-H2','H2-He']))
tm_gpu.add_contribution(RayleighCuda())
tm_gpu.build()

# %% [markdown]
# Lets assess the performance:

# %%
# Warmup (load files etc.)
tm_cpu.model()
tm_gpu.model()

# %timeit tm_cpu.model()
# %timeit tm_gpu.model()
# Out:
# 482 ms ± 9.68 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 32.6 ms ± 3.79 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Lets try setting up a retrieval as before:

# %%
from taurex.spectrum import ObservedSpectrum
from taurex.optimizer import NestleOptimizer

obs = ObservedSpectrum("./quickstart.dat")

opt = NestleOptimizer(observed=obs, model=tm_gpu, num_live_points=100)
opt.set_model(tm_gpu)

# %%
from taurex.core.priors import Uniform, LogUniform

opt.enable_fit("T")
opt.set_prior("T", Uniform(bounds=(1000.0, 2000.0)))

opt.enable_fit("planet_radius")
opt.set_prior("planet_radius", Uniform(bounds=(0.5,2.0)))

opt.enable_fit("H2O")
opt.set_prior("H2O", LogUniform(bounds=(-12,-3)))

opt.enable_fit("CH4")
opt.set_prior("CH4", LogUniform(bounds=(-12,-3)))

# %% [markdown]
# Now lets fit:

# %%
solution = opt.fit()
# Out:
# it=  1401 logz=1695.662728

# %% [markdown]
# Lets loop and plot each solution

# %%
import matplotlib.pyplot as plt
obin = obs.create_binner()

for sol,optimized_map,optimized_value,values in opt.get_solution():
    opt.update_model(optimized_map)
    plt.figure()
    plt.errorbar(obs.wavelengthGrid,obs.spectrum,obs.errorBar,label='Obs')
    plt.plot(obs.wavelengthGrid,obin.bin_model(tm_gpu.model(obs.wavenumberGrid))[1],label='TM')
    plt.legend()
    plt.show()

# %% [markdown]
# Lets plot the corners
